# %% [markdown]
# #  Step 0 Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #  Step 1 Importing Dataset

# %%
df = pd.read_csv('Movie_Id_Titles')

# %%
df
# Out:
#       item_id                                      title
# 0           1                           Toy Story (1995)
# 1           2                           GoldenEye (1995)
# 2           3                          Four Rooms (1995)
# 3           4                          Get Shorty (1995)
# 4           5                             Copycat (1995)
# ...       ...                                        ...
# 1677     1678                          Mat' i syn (1997)
# 1678     1679                           B. Monkey (1998)
# 1679     1680                       Sliding Doors (1998)
# 1680     1681                        You So Crazy (1994)
# 1681     1682  Scream of Stone (Schrei aus Stein) (1991)
#
# [1682 rows x 2 columns]

# %%
df.head(5)
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
df.tail(5)
# Out:
#       item_id                                      title
# 1677     1678                          Mat' i syn (1997)
# 1678     1679                           B. Monkey (1998)
# 1679     1680                       Sliding Doors (1998)
# 1680     1681                        You So Crazy (1994)
# 1681     1682  Scream of Stone (Schrei aus Stein) (1991)

# %%
df_rating = pd.read_csv('u.data', sep='\t', names=['user_id', 'item_id', 'rating', 'timestamp'])

# %%
df_rating
# Out:
#         user_id  item_id  rating  timestamp
# 0             0       50       5  881250949
# 1             0      172       5  881250949
# 2             0      133       1  881250949
# 3           196      242       3  881250949
# 4           186      302       3  891717742
# ...         ...      ...     ...        ...
# 99998       880      476       3  880175444
# 99999       716      204       5  879795543
# 100000      276     1090       1  874795795
# 100001       13      225       2  882399156
# 100002       12      203       3  879959583
#
# [100003 rows x 4 columns]

# %%
df_rating.drop(['timestamp'], axis = 1, inplace = True)

# %%
df_rating
# Out:
#         user_id  item_id  rating
# 0             0       50       5
# 1             0      172       5
# 2             0      133       1
# 3           196      242       3
# 4           186      302       3
# ...         ...      ...     ...
# 99998       880      476       3
# 99999       716      204       5
# 100000      276     1090       1
# 100001       13      225       2
# 100002       12      203       3
#
# [100003 rows x 3 columns]

# %%
df_rating.describe()
# Out:
#              user_id        item_id         rating
# count  100003.000000  100003.000000  100003.000000
# mean      462.470876     425.520914       3.529864
# std       266.622454     330.797791       1.125704
# min         0.000000       1.000000       1.000000
# 25%       254.000000     175.000000       3.000000
# 50%       447.000000     322.000000       4.000000
# 75%       682.000000     631.000000       4.000000
# max       943.000000    1682.000000       5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1682 entries, 0 to 1681
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   item_id  1682 non-null   int64
#  1   title    1682 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 26.4+ KB

# %%
df_rating = pd.merge(df_rating, df, on = 'item_id')

# %%
df_rating
# Out:
#         user_id  item_id  rating  \
# 0             0       50       5
# 1           290       50       5
# 2            79       50       4
# 3             2       50       5
# 4             8       50       5
# ...         ...      ...     ...
# 99998       840     1674       4
# 99999       655     1640       3
# 100000      655     1637       3
# 100001      655     1630       3
# 100002      655     1641       3
#
#                                                     title
# 0                                        Star Wars (1977)
# 1                                        Star Wars (1977)
# 2                                        Star Wars (1977)
# 3                                        Star Wars (1977)
# 4                                        Star Wars (1977)
# ...                                                   ...
# 99998                                   Mamma Roma (1962)
# 99999                              Eighth Day, The (1996)
# ...

# %%
df_rating.shape
# Out:
# (100003, 4)

# %%
df_rating.groupby('title')['rating'].describe()
# Out:
#                                        count      mean       std  min   25%  \
# title
# 'Til There Was You (1997)                9.0  2.333333  1.000000  1.0  2.00
# 1-900 (1994)                             5.0  2.600000  1.516575  1.0  1.00
# 101 Dalmatians (1996)                  109.0  2.908257  1.076184  1.0  2.00
# 12 Angry Men (1957)                    125.0  4.344000  0.719588  2.0  4.00
# 187 (1997)                              41.0  3.024390  1.172344  1.0  2.00
# ...                                      ...       ...       ...  ...   ...
# Young Guns II (1990)                    44.0  2.772727  1.008421  1.0  2.00
# Young Poisoner's Handbook, The (1995)   41.0  3.341463  1.237129  1.0  3.00
# Zeus and Roxanne (1997)                  6.0  2.166667  0.983192  1.0  1.25
# unknown                                  9.0  3.444444  1.130388  1.0  3.00
# Á köldum klaka (Cold Fever) (1994)       1.0  3.000000       NaN  3.0  3.00
#
# ...

# %%
df_mean = df_rating.groupby('title')['rating'].describe()['mean']

# %%
df_mean
# Out:
# title
# 'Til There Was You (1997)                2.333333
# 1-900 (1994)                             2.600000
# 101 Dalmatians (1996)                    2.908257
# 12 Angry Men (1957)                      4.344000
# 187 (1997)                               3.024390
#                                            ...
# Young Guns II (1990)                     2.772727
# Young Poisoner's Handbook, The (1995)    3.341463
# Zeus and Roxanne (1997)                  2.166667
# unknown                                  3.444444
# Á köldum klaka (Cold Fever) (1994)       3.000000
# Name: mean, Length: 1664, dtype: float64

# %%
df_count = df_rating.groupby('title')['rating'].describe()['count']
df_count
# Out:
# title
# 'Til There Was You (1997)                  9.0
# 1-900 (1994)                               5.0
# 101 Dalmatians (1996)                    109.0
# 12 Angry Men (1957)                      125.0
# 187 (1997)                                41.0
#                                          ...
# Young Guns II (1990)                      44.0
# Young Poisoner's Handbook, The (1995)     41.0
# Zeus and Roxanne (1997)                    6.0
# unknown                                    9.0
# Á köldum klaka (Cold Fever) (1994)         1.0
# Name: count, Length: 1664, dtype: float64

# %%
rating = pd.concat([df_mean, df_count], axis=1)
rating
# Out:
#                                            mean  count
# title
# 'Til There Was You (1997)              2.333333    9.0
# 1-900 (1994)                           2.600000    5.0
# 101 Dalmatians (1996)                  2.908257  109.0
# 12 Angry Men (1957)                    4.344000  125.0
# 187 (1997)                             3.024390   41.0
# ...                                         ...    ...
# Young Guns II (1990)                   2.772727   44.0
# Young Poisoner's Handbook, The (1995)  3.341463   41.0
# Zeus and Roxanne (1997)                2.166667    6.0
# unknown                                3.444444    9.0
# Á köldum klaka (Cold Fever) (1994)     3.000000    1.0
#
# [1664 rows x 2 columns]

# %%
rating.reset_index()
# Out:
#                                       title      mean  count
# 0                 'Til There Was You (1997)  2.333333    9.0
# 1                              1-900 (1994)  2.600000    5.0
# 2                     101 Dalmatians (1996)  2.908257  109.0
# 3                       12 Angry Men (1957)  4.344000  125.0
# 4                                187 (1997)  3.024390   41.0
# ...                                     ...       ...    ...
# 1659                   Young Guns II (1990)  2.772727   44.0
# 1660  Young Poisoner's Handbook, The (1995)  3.341463   41.0
# 1661                Zeus and Roxanne (1997)  2.166667    6.0
# 1662                                unknown  3.444444    9.0
# 1663     Á köldum klaka (Cold Fever) (1994)  3.000000    1.0
#
# [1664 rows x 3 columns]

# %%
rating['mean'].plot(bins = 100, kind = 'hist', color = 'y')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
rating['count'].plot(bins = 100, kind = 'hist', color = 'b')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#when was the rating rated 5
rating[rating['mean']==5]
# Out:
#                                                    mean  count
# title
# Aiqing wansui (1994)                                5.0    1.0
# Entertaining Angels: The Dorothy Day Story (1996)   5.0    1.0
# Great Day in Harlem, A (1994)                       5.0    1.0
# Marlene Dietrich: Shadow and Light (1996)           5.0    1.0
# Prefontaine (1997)                                  5.0    3.0
# Saint of Fort Washington, The (1993)                5.0    2.0
# Santa with Muscles (1996)                           5.0    2.0
# Someone Else's America (1995)                       5.0    1.0
# Star Kid (1997)                                     5.0    3.0
# They Made Me a Criminal (1939)                      5.0    1.0

# %%
#movie rated more times count
rating.sort_values('count', ascending=False).head(100)
# Out:
#                                   mean  count
# title
# Star Wars (1977)              4.359589  584.0
# Contact (1997)                3.803536  509.0
# Fargo (1996)                  4.155512  508.0
# Return of the Jedi (1983)     4.007890  507.0
# Liar Liar (1997)              3.156701  485.0
# ...                                ...    ...
# Aladdin (1992)                3.812785  219.0
# Babe (1995)                   3.995434  219.0
# Volcano (1997)                2.808219  219.0
# To Kill a Mockingbird (1962)  4.292237  219.0
# Murder at 1600 (1997)         3.087156  218.0
#
# [100 rows x 2 columns]

# %%
#movie rated few times count
rating.sort_values('count', ascending=True).head(100)
# Out:
#                                                     mean  count
# title
# Á köldum klaka (Cold Fever) (1994)                   3.0    1.0
# Mille bolle blu (1993)                               1.0    1.0
# Mat' i syn (1997)                                    1.0    1.0
# Marlene Dietrich: Shadow and Light (1996)            5.0    1.0
# Man from Down Under, The (1943)                      1.0    1.0
# ...                                                  ...    ...
# The Courtyard (1995)                                 1.0    1.0
# Vie est belle, La (Life is Rosey) (1987)             1.0    1.0
# Silence of the Palace, The (Saimt el Qusur) (1994)   3.0    1.0
# Very Natural Thing, A (1974)                         1.0    1.0
# Vermont Is For Lovers (1992)                         1.0    1.0
#
# [100 rows x 2 columns]

# %% [markdown]
# #  Step 3 To perform Item-based Collaborative Filtering on One Movie Sample

# %%
df_matrix = df_rating.pivot_table(index = 'user_id', columns = 'title', values = 'rating')
df_matrix
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# ...                            ...           ...                    ...
# 939                            NaN           NaN                    NaN
# 940                            NaN           NaN                    NaN
# 941                            NaN           NaN                    NaN
# 942                            NaN           NaN                    NaN
# 943                            NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# ...

# %%
titanic = df_matrix['Titanic (1997)']
titanic
# Out:
# user_id
# 0      NaN
# 1      NaN
# 2      5.0
# 3      NaN
# 4      NaN
#       ...
# 939    NaN
# 940    5.0
# 941    NaN
# 942    3.0
# 943    NaN
# Name: Titanic (1997), Length: 944, dtype: float64

# %%
starwars = df_matrix['Star Wars (1977)']
starwars
# Out:
# user_id
# 0      5.0
# 1      5.0
# 2      5.0
# 3      NaN
# 4      5.0
#       ...
# 939    NaN
# 940    4.0
# 941    NaN
# 942    5.0
# 943    4.0
# Name: Star Wars (1977), Length: 944, dtype: float64

# %%
titanic_correlation = pd.DataFrame(df_matrix.corrwith(titanic),  columns = ['Correlation'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\numpy\lib\function_base.py:2551: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\Users\HP\anaconda3\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
titanic_correlation = titanic_correlation.join(rating['count'])
titanic_correlation
# Out:
#                                        Correlation  count
# title
# 'Til There Was You (1997)                -0.062017    9.0
# 1-900 (1994)                                   NaN    5.0
# 101 Dalmatians (1996)                     0.120113  109.0
# 12 Angry Men (1957)                       0.077700  125.0
# 187 (1997)                                0.315654   41.0
# ...                                            ...    ...
# Young Guns II (1990)                      0.317274   44.0
# Young Poisoner's Handbook, The (1995)     0.356783   41.0
# Zeus and Roxanne (1997)                        NaN    6.0
# unknown                                        NaN    9.0
# Á köldum klaka (Cold Fever) (1994)             NaN    1.0
#
# [1664 rows x 2 columns]

# %%
titanic_correlation.sort_values('Correlation', ascending = False)
# Out:
#                                           Correlation  count
# title
# Nadja (1994)                                      1.0    8.0
# Pest, The (1997)                                  1.0    8.0
# Savage Nights (Nuits fauves, Les) (1992)          1.0    3.0
# For Ever Mozart (1996)                            1.0    3.0
# Jerky Boys, The (1994)                            1.0    3.0
# ...                                               ...    ...
# Yankee Zulu (1994)                                NaN    1.0
# You So Crazy (1994)                               NaN    1.0
# Zeus and Roxanne (1997)                           NaN    6.0
# unknown                                           NaN    9.0
# Á köldum klaka (Cold Fever) (1994)                NaN    1.0
#
# [1664 rows x 2 columns]

# %%
    titanic_correlation[titanic_correlation['count']>80].sort_values('Correlation', ascending = False).head()
# Out:
#                               Correlation  count
# title
# Titanic (1997)                   1.000000  350.0
# River Wild, The (1994)           0.497600  146.0
# Abyss, The (1989)                0.472103  151.0
# Bram Stoker's Dracula (1992)     0.443560  120.0
# True Lies (1994)                 0.435104  208.0

# %% [markdown]
# #   Step 4 Create An item based Collaborative Filter on Entire dataset

# %%
df_matrix
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# ...                            ...           ...                    ...
# 939                            NaN           NaN                    NaN
# 940                            NaN           NaN                    NaN
# 941                            NaN           NaN                    NaN
# 942                            NaN           NaN                    NaN
# 943                            NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# ...

# %%
movie_correlation = df_matrix.corr(method = 'pearson', min_periods = 80)

# %%
movie_correlation
# Out:
# title                                  'Til There Was You (1997)  \
# title
# 'Til There Was You (1997)                                    NaN
# 1-900 (1994)                                                 NaN
# 101 Dalmatians (1996)                                        NaN
# 12 Angry Men (1957)                                          NaN
# 187 (1997)                                                   NaN
# ...                                                          ...
# Young Guns II (1990)                                         NaN
# Young Poisoner's Handbook, The (1995)                        NaN
# Zeus and Roxanne (1997)                                      NaN
# unknown                                                      NaN
# Á köldum klaka (Cold Fever) (1994)                           NaN
#
# title                                  1-900 (1994)  101 Dalmatians (1996)  \
# title
# 'Til There Was You (1997)                       NaN                    NaN
# ...

# %%
myratings = pd.read_csv('My_Ratings.csv')
myratings
# Out:
#          Movie Name  Ratings
# 0  Liar Liar (1997)        5
# 1  Star Wars (1977)        1

# %%
myratings['Movie Name'][0]
# Out:
# 'Liar Liar (1997)'

# %%
similar_movies_list = pd.Series()
for i in range(0, 2):
    similar_movie = movie_correlation[myratings['Movie Name'][i]].dropna() # Get same movies with same ratings
    similar_movie = similar_movie.map(lambda x: x * myratings['Ratings'][i]) # Scale the similarity by your given ratings
    similar_movies_list = similar_movies_list.append(similar_movie)
# Out:
# <ipython-input-68-0f9cbe166c58>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   similar_movies_list = pd.Series()

# %%
similar_movies_list.sort_values(inplace = True, ascending = False)
print (similar_movies_list.head(10))
# Out:
# Liar Liar (1997)                             5.000000
# Con Air (1997)                               2.349141
# Pretty Woman (1990)                          2.348951
# Michael (1996)                               2.210110
# Indiana Jones and the Last Crusade (1989)    2.072136
# Top Gun (1986)                               2.028602
# G.I. Jane (1997)                             1.989656
# Multiplicity (1996)                          1.984302
# Grumpier Old Men (1995)                      1.953494
# Ghost and the Darkness, The (1996)           1.895376
# dtype: float64
